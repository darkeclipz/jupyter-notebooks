# %% [markdown]
# # Monte Carlo Strategy Backtesting

# %%
# %pylab inline
import pandas as pd
from scipy.stats import norm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Remove trailing zeros

# %% [markdown]
# When creating moving averages we are losing a few periods at the head of the series. We want to fill this up with the first set value that we encounter in the series.

# %%
def remove_trailing_zeros(values):
    """Replace every 0 with 'nan' and return a copy."""
    start = 0
    for i in range(0, len(values)):
        start = i
        if values[i] != 0:
            break
    for i in range(0, start):
        values[i] = values[start]   
    return values

# %% [markdown]
# ### Init

# %% [markdown]
# Initializing the Monte Carlo simulation with variables:
#
# 1. $u$ = the log mean
# 2. $Var$ = the log variance
# 3. $\text{Drift} = u - 0.5 \cdot \text{Var}$
# 4. $\text{Stdev} = \sqrt{\text{Var}}$ (standard deviation)

# %% [markdown]
# The following values have been calculated for Bitcoin for a time period of the previous three years.
#
# * $u = 0.003717834$.
# * $\text{Var} = 0.00172476$

# %%
#u = 0.003717834
u = 0.003717834
var = 0.00172476
drift = u - (0.5 * var)
stdev = math.sqrt(var)

# %%
def generate_monte_carlo_chart(drift, stdev, t_intervals, start):
    daily_returns = np.exp(drift + stdev * norm.ppf(np.random.rand(t_intervals, 1)))
    price_list = np.zeros_like(daily_returns)
    price_list[0] = start
    for t in range(1, t_intervals):
        price_list[t] = price_list[t - 1] * daily_returns[t]
    return price_list

# %% [markdown]
# ### Run the simulation

# %%
chart = generate_monte_carlo_chart(drift, stdev, 365*3, 500)

# %% [markdown]
# ## Indicators

# %% [markdown]
# ### Simple Moving Average

# %%
def sma(values, n):
    sma = np.zeros_like(values)
    for i in range(n, len(values)):
        avg = np.sum(values[i-n:i])/n
        sma[i] = avg
    return remove_trailing_zeros(sma)

# %% [markdown]
# ### MACD

# %%
def macd(values, ma1, ma2, sl):
    macd = ma2 - ma1
    sma = np.ones_like(values) * macd[sl]
    for i in range(sl-1, len(macd)):
        avg = np.sum(macd[i-sl:i])/sl
        sma[i] = avg
    return [macd, sma]

# %% [markdown]
# ### Calculating the indicators

# %%
sma7 = sma(chart, 7)
sma14 = sma(chart, 14)
sma26 = sma(chart, 26)
sma12 = sma(chart, 12)
macd, sl = macd(chart, sma26, sma12, 9)

# %% [markdown]
# ## Plotting the Monte Carlo series and Indicators

# %%
plt.figure(figsize=(16,10))
plt.subplot(2,1,1)
plt.plot(chart, c='lightgrey', lw=3);
plt.plot(sma7, c='b')
plt.plot(sma14, c='r')
legend(['Price', 'SMA7', 'SMA14']);
grid(linestyle='--')

plt.subplot(2,1,2)
plt.plot(macd, c='b')
plt.plot(sl, c='r')
#plt.fill_between(range(0, len(macd_area)), 0, np.array(macd_area), facecolor='lightgray')
plt.axhline(0,c='black',lw=2, linestyle='solid')
legend(['MACD', 'Signal line']);

# %% [markdown]
# ## Strategies

# %% [markdown]
# ### HODL

# %% [markdown]
# Easy thing to do...

# %%
coefficient = chart[len(chart)-1]/chart[0]
print('Hodling yields: %f' % coefficient * 100)
# Out:
# Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349Hodling yields: 107.863349

# %% [markdown]
# ### MACD Crossover Strategy

# %% [markdown]
# This is a very simple strategy where we go long when the MACD crosses into the positive zone and go short when the MACD is in the negative zone.

# %% [markdown]
# #### Generating signals

# %%
start = 0
for i in range(0,len(sl)):
    start = i
    if not np.isnan(sl[i]):
        break

# %%
macd_prev = sl[i]
signals = []
for i in range(start, len(chart)):
    if macd_prev < 0 and sl[i] > 0:
        signals.append(['buy', i])
    elif macd_prev > 0 and sl[i] < 0:
        signals.append(['sell', i])
    macd_prev = sl[i]

if signals[len(signals)-1][0] == 'buy':
    signals.append(['sell', len(chart)-1])

# %%
len(signals)
signals[-1]
# Out:
# ['sell', 1094]

# %% [markdown]
# #### Plotting the signals

# %%
plt.figure(figsize=(16,10))
plt.subplot(2,1,1)
plt.plot(chart, c='lightgrey', lw=3);
plt.plot(sma7, c='b')
plt.plot(sma14, c='r')
legend(['Price', 'SMA7', 'SMA14']);
grid(linestyle='--')
for s in signals:
    color = 'red'
    if s[0] == 'buy':
        color = 'green'
    plt.axvline(s[1],c=color,lw=1, linestyle='--')
    
plt.subplot(2,1,2)
plt.plot(macd, c='b')
plt.plot(sl, c='r')
#plt.fill_between(range(0, len(macd_area)), 0, macd_area, facecolor='lightgray')
plt.axhline(0,c='black',lw=2, linestyle='solid')
plt.tight_layout(h_pad=0)
legend(['MACD', 'Signal line']);
for s in signals:
    color = 'red'
    if s[0] == 'buy':
        color = 'green'
    plt.axvline(s[1],c=color,lw=1, linestyle='--')

# %% [markdown]
# The strategy is overtrading a lot which in the main cause for it's poor results.

# %% [markdown]
# #### Stats

# %%
trades = []
bought_at = 0
no_of_trades = 0
losing_streak = 0
longest_losing_streak = 0
equity_start = 1000
equity = equity_start

for i in range(0,len(signals)-1):
    if signals[i][0] == 'buy':
        bought_at = i
    else:
        coefficient = chart[bought_at]/chart[i]
        equity *= coefficient
        
        if coefficient < 1:
            losing_streak += 1
            if losing_streak > longest_losing_streak:
                longest_losing_streak = losing_streak
        else:
            losing_streak = 0
        trades.append([signals[i][1], coefficient])
        no_of_trades += 1

# %%
index, coeff = zip(*trades)
equity
# Out:
# array([ 997.3953186])

# %%
print('Equity after %i trades %f (Started with %i)' % (len(trades), equity, equity_start))
# Out:
# Equity after 10 trades 997.395319 (Started with 1000)

# %%
print('Stdev: %f' % math.sqrt(np.var(coeff)))
# Out:
# Stdev: 0.035259

# %%
print('Longest losing streak: %i' % longest_losing_streak)
# Out:
# Longest losing streak: 4

# %% [markdown]
# ## To do

# %% [markdown]
# Add:
#
# * Equity curve plot
# * Exponential Moving Average
# * Relative Strength Index
# * Bollinger Bands
# * Fix that stupid HODLing message
