# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Technical Analysis Library (*ta_lib*)

# %%
import poloniex as plnx
import pandas as pd 
from datetime import datetime, timedelta

# %%
pair = 'USDT_BTC'
timeframe = 15 * 60
end = datetime.utcnow()
start = end - timedelta(days=0.5)
verbose_logging = True
chart = plnx.get_chart(pair, timeframe, start, end, verbose_logging)
# Out:
# https://poloniex.com/public?command=returnChartData&currencyPair=USDT_BTC&start=1524972260&end=1525015460&period=900
# Retrieved 48 records.

# %% [markdown]
# ## Daily returns

# %%
def daily_returns(df, source_column = 'close', target_column = 'daily_return'): 
    df[target_column] = df[source_column] - df[source_column].shift(1)

# %%
daily_returns(chart)

# %%
chart.head()
# Out:
#          close                 date         high          low         open  \
# 0  9465.394474  2018-04-29 05:30:00  9509.723249  9448.758000  9509.591968
# 1  9484.977577  2018-04-29 05:45:00  9489.000000  9453.238698  9465.394474
# 2  9500.000000  2018-04-29 06:00:00  9510.500000  9467.067099  9485.022338
# 3  9490.679353  2018-04-29 06:15:00  9518.509490  9485.295310  9510.000000
# 4  9497.300658  2018-04-29 06:30:00  9507.084768  9471.145170  9500.170032
#
#    daily_return
# 0           NaN
# 1     19.583103
# 2     15.022423
# 3     -9.320647
# 4      6.621305

# %%
plot(chart['daily_return'], c='r')

# %% [markdown]
# ## Moving Averages

# %% [markdown]
# ### Simple Moving Average (SMA)

# %% [markdown]
# A simple moving average over $n$ periods, and weights in each period with equal weight.

# %%
x, y = range(15), [1/15]*15
bar(x, y, facecolor='r')
axes = plt.gca()
axes.set_ylim(0,0.2)
# Out:
# (0, 0.2)

# %%
def sma(df, periods = 7, source_column = 'close', target_column = 'sma'):
    df['{}{}'.format(target_column, periods)] = df[source_column].rolling(window=periods).mean()

# %%
sma(chart)

# %%
chart.head()
# Out:
#          close                 date         high          low         open  \
# 0  9465.394474  2018-04-29 05:30:00  9509.723249  9448.758000  9509.591968
# 1  9484.977577  2018-04-29 05:45:00  9489.000000  9453.238698  9465.394474
# 2  9500.000000  2018-04-29 06:00:00  9510.500000  9467.067099  9485.022338
# 3  9490.679353  2018-04-29 06:15:00  9518.509490  9485.295310  9510.000000
# 4  9497.300658  2018-04-29 06:30:00  9507.084768  9471.145170  9500.170032
#
#    daily_return  sma7
# 0           NaN   NaN
# 1     19.583103   NaN
# 2     15.022423   NaN
# 3     -9.320647   NaN
# 4      6.621305   NaN

# %%
plot(chart['close'], c='black')
plot(chart['sma7'], c='r')

# %% [markdown]
# ### Weighted Moving Average (WMA)

# %% [markdown]
# Moving average where the weight of later periods is linearly decreasing.

# %%
def triangular(n): return n * (n + 1) / 2

# %%
n = 15
x = np.linspace(1, n, n)
y = (n-x+1) / triangular(n)
bar(x, y, facecolor='r')
axes = plt.gca()
axes.set_ylim(0,0.2)
# Out:
# (0, 0.2)

# %%
from scipy.ndimage.interpolation import shift
from pandas import Series

# %%
def wma(df, periods = 7, source_column = 'close', target_column = 'wma'):
    x = np.linspace(1, periods, periods)
    weights = (periods-x+1) / triangular(periods)
    wma = np.convolve(weights, df[source_column], 'valid')
    wma.resize(len(wma)+periods-1)
    wma = Series(wma)
    wma = wma.shift(periods-1)
    df['{}{}'.format(target_column, periods)] = wma

# %%
wma(chart)

# %%
plot(chart['close'], c='black')
plot(chart['wma7'], c='r')

# %% [markdown]
# ### Exponential Moving Average (EMA)

# %% [markdown]
# Moving average where the weight of later periods is exponentially decreasing.

# %%
weights = np.exp(1-linspace(-1,1,n))
weights /= weights.sum()
bar(x, weights, facecolor='r')
axes = plt.gca()
axes.set_ylim(0,0.2)
# Out:
# (0, 0.2)

# %%
from scipy.ndimage.interpolation import shift
from pandas import Series

# %%
def ema(df, periods = 7, source_column = 'close', target_column = 'ema'):
    weights = np.exp(1-np.linspace(-1, 1, periods))
    weights /= weights.sum()
    ema = np.convolve(weights, df[source_column], 'valid')
    ema.resize(len(ema)+periods-1)
    ema = Series(ema)
    ema = ema.shift(periods-1)
    df['{}{}'.format(target_column, periods)] = ema

# %%
ema(chart)

# %%
plot(chart['close'], c='black')
plot(chart['ema7'], c='r')

# %% [markdown]
# ### Comparison

# %% [markdown]
# Comparison between the SMA, WMA and EMA.

# %%
ema(chart)
plt.figure(figsize=(20,7))
plot(chart['close'], c='black')
plot(chart['ema7'], c='r')
plot(chart['wma7'], c='b')
plot(chart['sma7'], c='gray')
legend(['close', 'ema', 'wma', 'sma'])
grid();

# %% [markdown]
# ## Standard deviation

# %%
def std(df, periods = 20, source_column = 'close', target_column = 'std'):
    df['{}{}'.format(target_column, periods)] = df[source_column].rolling(window=periods).std()

# %%
std(chart)

# %%
chart.head()
# Out:
#          close                 date         high          low         open  \
# 0  9465.394474  2018-04-29 05:30:00  9509.723249  9448.758000  9509.591968
# 1  9484.977577  2018-04-29 05:45:00  9489.000000  9453.238698  9465.394474
# 2  9500.000000  2018-04-29 06:00:00  9510.500000  9467.067099  9485.022338
# 3  9490.679353  2018-04-29 06:15:00  9518.509490  9485.295310  9510.000000
# 4  9497.300658  2018-04-29 06:30:00  9507.084768  9471.145170  9500.170032
#
#    daily_return  sma7  wma7  ema7  std20
# 0           NaN   NaN   NaN   NaN    NaN
# 1     19.583103   NaN   NaN   NaN    NaN
# 2     15.022423   NaN   NaN   NaN    NaN
# 3     -9.320647   NaN   NaN   NaN    NaN
# 4      6.621305   NaN   NaN   NaN    NaN

# %%
plot(chart['std20'], c='r')

# %% [markdown]
# ## Bollinger Bands

# %% [markdown]
# Bollinger band is calculated as follows:
#
#  * Standard deviation ($\sigma$) moving average for $n$ periods.
#  * EMA for $n$ periods
#  * The upper band is $\text{EMA} + 2\sigma$.
#  * The lower band is $\text{EMA} - 2\sigma$.
#
# The default period is $20$.

# %%
def bbands(df, source_std = 'std20', source_ma = 'ema20', target_column = 'bb'):
    df['{}_mid'.format(target_column)] = df[source_ma]
    df['{}_upper'.format(target_column)] = df[source_ma] + 2*df[source_std]
    df['{}_lower'.format(target_column)] = df[source_ma] - 2*df[source_std]

# %%
ema(chart, 20)
bbands(chart)

# %%
chart.head()
# Out:
#          close                 date         high          low         open  \
# 0  9465.394474  2018-04-29 05:30:00  9509.723249  9448.758000  9509.591968
# 1  9484.977577  2018-04-29 05:45:00  9489.000000  9453.238698  9465.394474
# 2  9500.000000  2018-04-29 06:00:00  9510.500000  9467.067099  9485.022338
# 3  9490.679353  2018-04-29 06:15:00  9518.509490  9485.295310  9510.000000
# 4  9497.300658  2018-04-29 06:30:00  9507.084768  9471.145170  9500.170032
#
#    daily_return  sma7  wma7  ema7  std20  ema20  bb_mid  bb_upper  bb_lower
# 0           NaN   NaN   NaN   NaN    NaN    NaN     NaN       NaN       NaN
# 1     19.583103   NaN   NaN   NaN    NaN    NaN     NaN       NaN       NaN
# 2     15.022423   NaN   NaN   NaN    NaN    NaN     NaN       NaN       NaN
# 3     -9.320647   NaN   NaN   NaN    NaN    NaN     NaN       NaN       NaN
# 4      6.621305   NaN   NaN   NaN    NaN    NaN     NaN       NaN       NaN

# %%
plot(chart['close'], c='black')
plot(chart['ema20'], c='r')
plot(chart['bb_upper'], c='gray')
plot(chart['bb_lower'], c='gray')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %% [markdown]
# The relative strength index is calculated with the following formula:
#
#  * $\text{RSI}=100-100/(1+\text{RS})$
#  * $\text{RS}=U / D$
#  * $U$ is EMA of all positive moves in the last $n$ periods.
#  * $D$ is EMA of (absolute values of) all negative moves in the last $n$ periods.
#  * $n$ is the period of RSI.

# %%
chart['closing_gains'] = chart['daily_return'].apply(lambda x: max(x, 0))
chart['closing_losses'] = chart['daily_return'].apply(lambda x: abs(min(x, 0)))
ema(chart, 14, 'closing_gains', 'closing_gains_ema')
ema(chart, 14, 'closing_losses', 'closing_losses_ema')
chart['rs'] = chart['closing_gains_ema14'] / chart['closing_losses_ema14']
chart['rsi'] = 100 - (100 / (1 + chart['rs']))

# %%
fig, ax = plt.subplots()
plot(chart['rsi'], c='black')
plt.axhline(y=80, c='r')
plt.axhline(y=20, c='lime')
ax.set_ylim(0, 100)
fill_between(list(chart.index), 20, 80, color='grey', alpha=0)

# %%
def rsi(df, periods = 14, source_column='daily_return', target_column='rsi'):
    df['closing_gains'] = df[source_column].apply(lambda x: max(x, 0))
    df['closing_losses'] = df[source_column].apply(lambda x: abs(min(x, 0)))
    ema(df, periods, 'closing_gains', 'closing_gains_ema')
    ema(df, periods, 'closing_losses', 'closing_losses_ema')
    df['rs'] = df['closing_gains_ema{}'.format(periods)] / df['closing_losses_ema{}'.format(periods)]
    df[target_column] = 100 - (100 / (1 + df['rs']))

# %% [markdown]
# ## Parabolic SAR (stop and reverse)
