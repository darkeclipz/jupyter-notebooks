# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Trading simulator

# %% [markdown]
# ## Overview of libraries

# %% [markdown]
# The code below is meant to give an impression of the current implementation of the libraries that are customly developed for the algorithmic trading algorithm.

# %% [markdown]
# ### Imports

# %%
import poloniex as plnx
import ta_lib as ta
from datetime import datetime, timedelta
from matplotlib.finance import candlestick2_ohlc

# %% [markdown]
# ### Chart settings

# %%
pair = 'USDT_BTC'
timeframe = 30*60
end = datetime.utcnow()
start = end - timedelta(days=4)

# %%
chart = plnx.get_chart(pair, timeframe, start, end)

# %% [markdown]
# ### Technical indicators

# %%
ta.daily_returns(chart)
ta.ema(chart)    # default n=7
ta.ema(chart, 23)
ta.bbands(chart) # default n=20
ta.rsi(chart)    # default n=14

# %% [markdown]
# ### Plotting

# %%
from matplotlib import gridspec

gs = gridspec.GridSpec(2, 1, height_ratios=[3,1])
f = plt.figure(figsize=(20,15))
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
candlestick2_ohlc(ax1, chart['open'], chart['high'], chart['low'], chart['close'], width=0.74, colorup='g', colordown='r', alpha=0.5)
ax1.plot(chart['ema7'], c='lime', lw=2)
ax1.plot(chart['ema23'], c='red', lw=2)
ax1.plot(chart['bb_mid'], c='gray', ls='dotted')
ax1.plot(chart['bb_upper'], c='gray', ls='dotted')
ax1.plot(chart['bb_lower'], c='gray', ls='dotted')
ax1.grid()
ax2.plot(list(chart.index), chart['rsi'], c='gray')
ax2.grid()
ax2.axhline(y=80, c='red', ls='dashed')
ax2.axhline(y=20, c='lime', ls='dashed')
ax2.fill_between(list(chart.index), 20, 80, color='grey', alpha=0) # 'kinda' corrects the x-axis for RSI 
f.subplots_adjust(hspace=0)

# %% [markdown]
# ### Data columns

# %%
chart.columns
# Out:
# Index(['close', 'date', 'high', 'low', 'open', 'daily_return', 'ema7', 'ema23',
#        'bb_mid', 'bb_upper', 'bb_lower', 'rsi'],
#       dtype='object')

# %% [markdown]
# ### Dataset

# %%
chart.head(50)
# Out:
#           close                 date         high          low         open  \
# 0   9023.255690  2018-04-25 20:00:00  9066.710479  8970.012338  9066.710479
# 1   8980.983393  2018-04-25 20:30:00  9049.977662  8954.090590  9010.021972
# 2   8981.452480  2018-04-25 21:00:00  9019.489409  8971.169727  8990.850464
# 3   8957.021972  2018-04-25 21:30:00  9008.748685  8950.000000  8972.479999
# 4   9055.066282  2018-04-25 22:00:00  9076.154307  8968.089805  8977.933352
# 5   9070.000000  2018-04-25 22:30:00  9121.112000  9055.000000  9055.066282
# 6   9127.862138  2018-04-25 23:00:00  9144.594407  9063.423139  9070.000000
# 7   9165.000000  2018-04-25 23:30:00  9165.000000  9115.862138  9134.771479
# 8   9107.487547  2018-04-26 00:00:00  9183.632825  9074.090590  9156.536008
# 9   8951.022350  2018-04-26 00:30:00  9128.997496  8940.090590  9091.090001
# 10  8859.114000  2018-04-26 01:00:00  9010.830669  8851.000000  8941.789680
# 41     45.824890  8834.671785  8836.944869  8835.422387  8951.181115
# 42    -29.824890  8825.201486  8834.110658  8831.116794  8942.788200
# 43     -5.863078  8815.665404  8830.384089  8826.914708  8936.818225
# 44     49.931539  8823.560108  8831.127524  8828.384523  8931.602152
# 45     49.831539  8846.345790  8837.046705  8836.641999  8945.342827
# 46    -49.900000  8848.446381  8837.804757  8838.141811  8947.219421
# 47     -7.860119  8848.245844  8837.338562  8838.198971  8945.976075
# 48     35.300119  8857.788253  8841.531447  8844.069146  8945.281406
# 49    -31.052833  8855.785803  8842.055177  8845.996895  8933.072667
#
#        bb_lower        rsi
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN
# 10          NaN        NaN
# 11          NaN        NaN
# 12          NaN        NaN
# 13          NaN        NaN
# 14          NaN  41.542507
# 15          NaN  34.023382
# 16          NaN  44.201615
# 17          NaN  46.595306
# 18          NaN  47.879633
# 19  8619.605163  41.105813
# 20  8617.609435  47.137975
# 21  8623.395451  55.543085
# 22  8626.087517  52.712767
# 23  8624.913893  51.607167
# 24  8634.663167  58.865534
# 25  8634.715462  42.717005
# 26  8653.493896  49.497654
# 27  8697.827556  52.076867
# 28  8716.480906  32.015212
# 29  8700.595023  31.851716
# 30  8686.532479  36.043265
# 31  8674.520628  35.488039
# 32  8696.803601  56.734198
# 33  8701.381552  60.510445
# 34  8705.351196  60.003080
# 35  8714.829914  53.380654
# 36  8718.989145  61.169266
# 37  8723.234168  68.136208
# 38  8725.246698  52.149622
# 39  8721.948401  43.510154
# 40  8713.705595  37.819536
# 41  8719.663658  49.575533
# 42  8719.445388  46.054304
# 43  8717.011191  44.947022
# 44  8725.166894  57.660635
# 45  8727.941172  67.078944
# 46  8729.064202  50.890666
# 47  8730.421867  48.516705
# 48  8742.856886  57.116098
# 49  8758.921123  49.161937

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# We want to be able to adjust the following parameters for the simulation:
#
# 1. Symbol
# 2. Timeframe
# 3. Stop loss strategy: `limit`, `trail`
# 4. Stop loss percentage (max losses before the trade is stopped out)
# 5. Amount of leverage used
# 6. Fee percentage per order
# 7. Initial balance
# 8. Lot sizing
# 9. Signals, when to go long and short

# %% [markdown]
# ## Simulation metrics

# %% [markdown]
# We want to able to track the following metrics:
#
# 1. Total trades
# 2. Winning trades
# 3. Losing trades
# 4. Win/loss ratio
# 5. Trades stopped out
# 6. Fee paid
# 7. Fee paid (cumulative)
# 8. Gains
# 9. Gains (cumulative)
# 10. Drawdown
# 11. Max drawdown
# 12. Risk/reward ratio
# 13. Risk/reward average

# %% [markdown]
# ## Simulation types

# %% [markdown]
# We want to support the following simulation types:
#
# 1. Single simulation
# 2. Multiple simulations for parameter tuning
