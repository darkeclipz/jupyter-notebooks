# %% [markdown]
# # Elfskot PyAPI

# %%
# Required packages:
# pip3 install requests pandas
import requests
import json
from enum import Enum
import pandas as pd

def head(s): return s[0] if len(s) > 0 else []
def tail(s): return s[1:]
def reverse(s): return s[::-1]
def last(s): return s[-1:]
def init(s): return s[0:len(s)-1]
def take(s, n): return s[:n]
def drop(s, n): return s[n:]
def product(s): return reduce(lambda x, y: x * y, s)

class TextType(Enum):
    Description = 0
    ExtendedDescription = 1
    MoreInfo = 2

class ElfskotApi():
    
    base_address = 'https://api.elfskot.cloud/api/2/'
    
    def __init__(self, application_id, secret):
        self.application_id = application_id
        self.secret = secret
        self.get_token()
    
    def get_token(self):
        payload = { 'clientId': self.application_id, 'secret': self.secret}
        result = requests.post(self.get_url('auth/elfskotconnectlogin'), json=payload)
        self.check_result(result)
        self.token = json.loads(result.text)['accessToken']
        
    def check_result(self, result):
        if result.status_code != 200:
            raise ValueError('Error: API returned status code {}'.format(result.status_code))
        return True
        
    def get_auth_header(self): return {'Authorization': 'bearer {}'.format(self.token)}
    def get_url(self, endpoint): return self.base_address + endpoint
    
    def http_return_if_valid(self, result):
        self.check_result(result)
        return json.loads(result.text)
    
    def http_get(self, endpoint):
        return self.http_return_if_valid(
            requests.get(self.get_url(endpoint), headers=self.get_auth_header())
        )
    
    def http_post(self, endpoint, o):
        return self.http_return_if_valid(
            requests.post(self.get_url(endpoint), json=o, headers=self.get_auth_header())
        )
    
    def http_put(self, endpoint, o):
        return self.http_return_if_valid(
            requests.put(self.get_url(endpoint), json=o, headers=self.get_auth_header())
        )
    
    def http_delete(self, endpoint, key):
        result = requests.delete(self.get_url(endpoint) + '/{}'.format(key), headers=self.get_auth_header())
        if result.status_code != 200: 
            raise ValueError('Error: API returned status code {}'.format(result.status_code))
            
    def all(self, endpoint): return self.http_get(endpoint)
    def get(self, endpoint, k): return head(self.http_get('{}?id={}'.format(endpoint, k)))
    def find(self, endpoint, p, v): return self.http_get('{}?{}={}'.format(endpoint, p, v))
    def first(self, endpoint, p, v): return head(self.find(endpoint, p, v))
    def new(self, endpoint, o): return self.http_post(endpoint, o)
    def update(self, endpoint, o): return self.http_put(endpoint, o)
    def delete(self, endpoint, k): self.http_delete(endpoint, k)  
    def help(self, endpoint): print('Model for {}:\r\n{}'
                                    .format(endpoint, list(self.first(endpoint, 'id', '').keys())))

# %%
db = ElfskotApi('69b1132c-df11-49d0-baf2-2d8f6ddfc4f1', 'lkmx41yu')

category = head(db.all('categories'))
uom = db.first('uom', 'description', 'Milli')

feature = {'name': 'Test feature', 
           'articleCode': 'ART-123', 
           'categoryId': category['id'], 
           'unitOfMeasurementId': uom['id'],
           'texts': [
               {'languageIso': 'en', 'type': TextType.Description.value, 'value': 'Example description'},
               {'languageIso': 'en', 'type': TextType.ExtendedDescription.value, 'value': 'Example description'},
               {'languageIso': 'en', 'type': TextType.MoreInfo.value, 'value': 'Example description'}
           ]}

feature = db.new('features', feature)
db.delete('features', feature['id'])

# %%
len(db.all('features'))
# Out:
# 245

# %%
db.help('featuremodels')
# Out:
# Model for featuremodels:
# ['rootFeatureId', 'status', 'revisionOf', 'rootFeature', 'order', 'displayPrices', 'autodeskUrn', 'steps', 'nodes', 'relationships', 'organizationSellsFeatureModels', 'dynamicGroups', 'id', 'organizationId', 'organizationName', 'creatorId', 'reference', 'synced', 'createdDate', 'updatedDate', 'customField1', 'customField2', 'customField3', 'customField4', 'customField5']

# %%
db.help('quotations')
# Out:
# Model for quotations:
# ['wholeSaleDiscountRows', 'quotationNumber', 'versionNumber', 'revisionOfId', 'status', 'isExpired', 'statusDescription', 'remarks', 'subject', 'expiresDate', 'deliverydate', 'debtorId', 'debtor', 'sellerLogo', 'sellerId', 'seller', 'shipToId', 'shipTo', 'propertyIds', 'margin', 'leaseTermType', 'leaseTermAmount', 'lines', 'materialList', 'currencyIso', 'languageIso', 'currency', 'exchangeRate', 'quotationTemplateId', 'quotationTemplate', 'files', 'totalDiscountAmt', 'totalDiscountPct', 'subTotalExclPrice', 'subTotalInclPrice', 'subTotalExclPriceLabel', 'subTotalInclPriceLabel', 'totalDiscountAmntLabel', 'totalExclPrice', 'totalInclPrice', 'totalPriceExclVATLabel', 'totalPriceInclVAT', 'totalPriceInclVATLabel', 'subTotalMargin', 'totalMargin', 'totalMarginLabel', 'totalMarginDiscount', 'totalMarginDiscountLabel', 'subTotalPurchasePrice', 'subTotalPurchasePriceLabel', 'subTotalMarginLabel', 'totalPurchasePriceLabel', 'wholeSaleDiscountAmtLabel', 'wholeSaleDiscountMinusAmtLabel', 'wholeSaleDiscountAmt', 'wholeSaleDiscountAmtNumberFormatted', 'wholeSaleDiscountPct', 'totalPriceInclVATNumberFormatted', 'totalDiscountNumberFormatted', 'totalPriceNumberFormatted', 'totalVatAmountNumberFormatted', 'subTotalNumberFormatted', 'totalDiscountPctNumberFormatted', 'formattedCreatedDate', 'formattedUpdatedDate', 'formattedExpiresDate', 'formattedDeliveryDate', 'organization', 'sellerName', 'id', 'organizationId', 'organizationName', 'creatorId', 'reference', 'synced', 'createdDate', 'updatedDate', 'customField1', 'customField2', 'customField3', 'customField4', 'customField5']

# %%
# Fetch all root features
for key in map(lambda x: x['rootFeatureId'], db.all('featuremodels')):
    feature = db.get('features', key)
    print(feature['name'])
# Out:
# S6000
# X8000
# Plateauaanhanger
# TEST relaties
# Betonput
# Test Wessel
# Formule cycle
# b_min

# %%
df = pd.DataFrame()
N = 5
names = ['b{}'.format(x) for x in range(N)]
codes = ['article-code'] * N
df['name'] = names
df['articleCode'] = codes
print(df)
for index, row in df.iterrows():
    feature = {'name': row['name'], 'articleCode': row['articleCode']}
    feature = db.new('features', feature)
    print('Created feature {} with id {}.'.format(feature['name'], feature['id']))
    db.delete('features', feature['id'])
# Out:
#   name   articleCode
# 0   b0  article-code
# 1   b1  article-code
# 2   b2  article-code
# 3   b3  article-code
# 4   b4  article-code
# Created feature b0 with id f598729a-3f0b-4ca7-82fa-08d649534e0a.
# Created feature b1 with id 776a36fa-bbf6-4856-82fb-08d649534e0a.
# Created feature b2 with id 1dfbf79f-95b5-45d0-82fc-08d649534e0a.
# Created feature b3 with id 77ad541a-fa9b-49ce-82fd-08d649534e0a.
# Created feature b4 with id ad2303ff-4408-4690-82fe-08d649534e0a.

# %%
db = ElfskotApi('71ac0e2b-b8a6-4d3f-84bb-ace0d0c43148', 'cwnwkiff')

# %%
db.all('features')
# Out:
# [{'articleCode': 'X_108',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/Elfvo.jpg',
#   'category': None,
#   'categoryId': '4fde3e79-c90e-4844-3d1b-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4867666+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '01574434-b7f4-42d4-b518-08d4ad0fbdd7',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'S6000',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '01d0e364-5ae1-4506-99a3-935d3634efa4',
#   'salesPrice': 42750.0,
#   'salesPriceLabel': '€ 42.750,00',
#   'stepValue': 0.0,
#   'subcategoryIds': ['5cec6233-c88a-4cca-dbc2-08d5cfa773a6',
#    '5da9354e-60f3-491d-4291-08d5fddd4fac',
#    '831a6ef6-d3d1-48e8-4292-08d5fddd4fac'],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080379+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_106',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/5f3319e0-0fe4-40f2-ad2b-95330ec49e70_image.png',
#   'category': None,
#   'categoryId': 'a51f921f-8ba4-47b1-3d23-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4867843+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '4dd8bf0f-4d4e-4ca3-b519-08d4ad0fbdd7',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Pegasus 19"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'c2c6f41c-4668-4831-b880-76c44bdb3f85',
#   'salesPrice': 630.0,
#   'salesPriceLabel': '€ 630,00',
#   'stepValue': 0.0,
#   'subcategoryIds': ['20fa710f-a0cb-4492-3fdb-08d5837b1545'],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['test:Volvo_s60_rim_fl',
#    'test:Volvo_s60_rim_rl',
#    'test:Volvo_s60_rim_fr',
#    'test:Volvo_s60_rim_rr'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681637+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_107',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/e62341c1-7a2b-438c-9795-e20307a5fe7f_image.png',
#   'category': None,
#   'categoryId': 'a51f921f-8ba4-47b1-3d23-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4868084+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'e95d700c-2405-4b7d-b51a-08d4ad0fbdd7',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Odysseus 18"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'f63d0e2e-ebe8-4eda-a25e-6283727c170f',
#   'salesPrice': 500.0,
#   'salesPriceLabel': '€ 500,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['Style_128_wheel_silver_mid_poly_03',
#    'Style_128_wheel_silver_mid_poly_00'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080649+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4868144+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ee808f22-1a67-4cd5-0ef4-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Cars',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.868167+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4868353+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'f7a1e556-a1f3-4cb1-0ef5-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 4.0,
#   'minValue': 4.0,
#   'name': 'Wheels',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': 3,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-17T10:35:17.8562628+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_100',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/068bf4da-ba72-4272-b61d-43f0e4e2404c_image.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4868412+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '375048b8-0b98-4a3f-0efb-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Snow tires 18"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'aeb1aac5-20fb-40fb-88f2-3c02a7422822',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681701+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_101',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/96331425-e98d-4835-8523-ab7dcd73a9b5_image.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4868689+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ccb59caa-397f-4af6-0efc-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'All Season tires 18"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '28372287-6d90-46a4-9cda-1eef51a85e02',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681717+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_102',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/11394c5b-97b1-4438-80c3-29f4bd74b3fb_image.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4869171+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '25d8bb0c-c8a7-4431-0efd-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Summer tires 18"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'ac4e77e8-e5a3-4a2f-8871-7641c8f0e401',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681732+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_110',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/diesel.JPG',
#   'category': None,
#   'categoryId': 'c6619774-d2aa-4bc4-3d1d-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4869475+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '5e7824c5-d4c1-46bb-0efe-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'TD4 Diesel',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'a8963b39-7fe5-4f11-8d7c-46d67d82127a',
#   'salesPrice': 3000.0,
#   'salesPriceLabel': '€ 3.000,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-01T10:10:00.4944082+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4869712+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'a1588be4-fbea-44a0-0f00-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Engine',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681764+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_112',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/V6.png',
#   'category': None,
#   'categoryId': 'c6619774-d2aa-4bc4-3d1d-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4869767+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '22ccab55-40a3-4d89-0f01-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'T5 benzinemotor',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'e7707ae3-13a0-432d-a0fb-f654f8b0be8b',
#   'salesPrice': 2800.0,
#   'salesPriceLabel': '€ 2.800,00',
#   'stepValue': 0.0,
#   'subcategoryIds': ['5da9354e-60f3-491d-4291-08d5fddd4fac'],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['Mesh_bonnet_Mat0'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-24T15:06:02.5715609+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_113',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/V6.png',
#   'category': None,
#   'categoryId': 'c6619774-d2aa-4bc4-3d1d-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4870048+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'df050182-7143-4134-0f02-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'T6',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'a2d287ae-2290-45ed-94c1-764aae0dccca',
#   'salesPrice': 6500.0,
#   'salesPriceLabel': '€ 6.500,00',
#   'stepValue': 0.0,
#   'subcategoryIds': ['5da9354e-60f3-491d-4291-08d5fddd4fac'],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-09-19T14:59:43.8925835+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_128',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/V8.JPG',
#   'category': None,
#   'categoryId': 'c6619774-d2aa-4bc4-3d1d-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4870332+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '5b9d3b42-6750-4da4-0f03-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'R-Star',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '2b64abde-d44f-49ee-8eb6-83a293d9ec9a',
#   'salesPrice': 10200.0,
#   'salesPriceLabel': '€ 10.200,00',
#   'stepValue': 0.0,
#   'subcategoryIds': ['5da9354e-60f3-491d-4291-08d5fddd4fac'],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681795+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4870577+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '1e75061f-4f9c-43c6-0f04-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Transmission',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681811+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_129',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/elfskot-debug-container/d91da7c6-a9c8-412c-a459-5bc9d5e72088_blob',
#   'category': None,
#   'categoryId': 'b60ee5fb-bb67-4420-3d1e-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.487081+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '3d3a74b4-1699-4b33-0f05-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': '5 versnellingen handgeschakeld',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '5b5df211-5f6c-47aa-953a-9d7622f97d6e',
#   'salesPrice': 300.0,
#   'salesPriceLabel': '€ 300,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080527+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_130',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/elfskot-debug-container/ac78148e-d2f1-4624-98dd-80961b255fa0_blob',
#   'category': None,
#   'categoryId': 'b60ee5fb-bb67-4420-3d1e-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4870866+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '4c0ea7ed-75ad-4ec8-0f06-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'M6',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '62f236a7-48fd-4ddf-af5a-89ce4cf61d76',
#   'salesPrice': 600.0,
#   'salesPriceLabel': '€ 600,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681842+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_131',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/elfskot-debug-container/e1221a88-1faf-4293-a43a-a5be9d2101c0_blob',
#   'category': None,
#   'categoryId': 'b60ee5fb-bb67-4420-3d1e-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.487113+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '33af3287-3692-4ca6-0f07-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'A8',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'b06f95c8-15af-4148-bba6-2705f0985bbe',
#   'salesPrice': 900.0,
#   'salesPriceLabel': '€ 900,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681857+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_115',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/54ee4ffb-d57b-45ee-80aa-1373f5014bf9_image.png',
#   'category': None,
#   'categoryId': '3ef76c1c-0d4a-4598-3d1f-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871344+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '200df15d-7c6b-4e57-0f09-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'White',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'e320521b-becf-4920-aaeb-34cebf5d6ee0',
#   'salesPrice': 600.0,
#   'salesPriceLabel': '€ 600,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080601+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_116',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/18fde24f-ce79-4d8e-a203-bf0727afd723_image.png',
#   'category': None,
#   'categoryId': '3ef76c1c-0d4a-4598-3d1f-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871399+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ebbb9e68-63da-40ac-0f0a-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Red',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '946a3c0a-c96a-47ab-8fff-1a1681dbef08',
#   'salesPrice': 900.0,
#   'salesPriceLabel': '€ 900,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681889+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_117',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/1b3b591d-0acc-4304-9a1f-f3232146029c_image.png',
#   'category': None,
#   'categoryId': '3ef76c1c-0d4a-4598-3d1f-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871624+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '46954d88-3724-40e5-0f0b-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Blue',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'b5753555-eb78-4255-8420-c71315c34df8',
#   'salesPrice': 900.0,
#   'salesPriceLabel': '€ 900,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T08:13:27.6103783+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_114',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/7148eeb1-712e-49a3-a866-cd81f4c784b0_image.png',
#   'category': None,
#   'categoryId': '3ef76c1c-0d4a-4598-3d1f-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871853+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '9a1f0968-527c-4794-0f0c-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Black',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '9fe4dcd3-6e6e-40e2-8f86-05766bc54fa0',
#   'salesPrice': 600.0,
#   'salesPriceLabel': '€ 600,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['Mesh_bonnet_Mat0'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-24T15:06:02.5715624+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_118',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/df741a2e-73d1-4b38-84e5-fcdfd025cd60_image.png',
#   'category': None,
#   'categoryId': '3ef76c1c-0d4a-4598-3d1f-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871909+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ef06905c-3a56-4613-0f0d-08d4adbb8acb',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Silver',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'cc9133f0-1527-44d2-827e-12190c1c5d95',
#   'salesPrice': 1200.0,
#   'salesPriceLabel': '€ 1.200,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681936+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_103',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/67a114cf-b5ea-4b0e-8793-82a0786c1a56_image.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4871968+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '60462002-675b-4d9a-685a-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Snow tires 19"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '826b1195-377f-4fd5-85b6-5cac5926374a',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681952+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_104',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/00000000-0000-0000-0000-000000000000/eee6d5a9-0b63-4cd8-b19f-c1e61b0b6f3b_img.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872047+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '15c970fa-366f-46a1-685b-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'All Season tires 19"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '82954e13-4035-49c9-a237-0d54c03d8692',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681967+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_105',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/c97c287d-537a-4165-8cbd-420628949508_image.png',
#   'category': None,
#   'categoryId': '1c52e16f-fb87-41dd-3d24-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872146+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '2ae66d43-0860-46b5-685c-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Summer tires 19"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'b622ddd4-1207-4720-8e9b-759c89d4eadc',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8681983+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/9c2ecc6f-25f6-459f-8241-c72a3528dece_image.png',
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4872248+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '7a38c736-dc21-433a-685d-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Snow tires',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682003+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/ed1009fb-bec1-44ea-a680-12cd33e3b510_image.png',
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4872327+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ef99303d-6c54-47d8-685e-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'All Season tires',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682019+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/e8222b1f-66b3-49e0-bcd1-a82cdb63d2e7_image.png',
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4872402+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '1910f47f-2e4a-4307-685f-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Summer tires',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '',
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682034+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4872482+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'f4ce1c70-b25b-40af-6863-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Raamomlijsting',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.868205+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_121',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/Comfort chassis',
#   'category': None,
#   'categoryId': '79d10665-18ca-4405-3d20-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872493+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'd770a68d-4a93-4b6a-6867-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Comfort chassis',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '38522d3d-31dd-46f4-86fb-fef32237de7a',
#   'salesPrice': 1200.0,
#   'salesPriceLabel': '€ 1.200,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080552+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_122',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/Sport Chassic',
#   'category': None,
#   'categoryId': '79d10665-18ca-4405-3d20-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872568+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '6af7ee2b-8f28-40e8-6868-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Sport Chassis',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '4cdac07b-b43c-4e76-8f65-1a84f5651706',
#   'salesPrice': 2400.0,
#   'salesPriceLabel': '€ 2.400,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-09-19T14:59:43.8925984+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_123',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/26dd0fa4-78ba-4b2a-9fbd-637f7da671a5_image.png',
#   'category': None,
#   'categoryId': '88e43ee0-be1c-4efe-3d21-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872647+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ca8c70f3-e8d9-4357-686a-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Black Leather',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'b37d6295-0e5c-4199-aff8-9705fb939634',
#   'salesPrice': 2700.0,
#   'salesPriceLabel': '€ 2.700,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682081+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_124',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/43e47cf6-7b13-4ac6-b00d-6d8a9c88ebcf_image.png',
#   'category': None,
#   'categoryId': '88e43ee0-be1c-4efe-3d21-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872703+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '7a9b2fd1-3eb4-40fd-686b-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Beige Leather',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'a0af8ad6-bf16-4555-b827-3d60aeae3639',
#   'salesPrice': 3300.0,
#   'salesPriceLabel': '€ 3.300,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080625+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-01-25T16:20:08.4872805+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'c4c5c674-7f7f-4f8d-686c-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Infotainment',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682111+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_132',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/dd730c29-c46a-486f-9e15-7e8c05ffe702_image.png',
#   'category': None,
#   'categoryId': 'dd2c73a1-007d-4c32-3d22-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4872861+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '28b566af-0de5-425e-686d-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Premium navigatie',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '3a087fa2-4c63-450a-ade6-df28f18b210a',
#   'salesPrice': 850.0,
#   'salesPriceLabel': '€ 850,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['test:polySurface8', 'Mesh_Volvo_s60_display'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682127+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_125',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/26d656c5-590b-4803-8901-219be694871d_image.png',
#   'category': None,
#   'categoryId': 'dd2c73a1-007d-4c32-3d22-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4873118+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'c9c6088b-f278-4432-686e-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'High Performance Audio',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '7b969572-ccf1-46d5-a295-454cf953b16c',
#   'salesPrice': 510.0,
#   'salesPriceLabel': '€ 510,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682143+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_126',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/4234abe6-b58e-4de2-be9f-86a44229903b_image.png',
#   'category': None,
#   'categoryId': 'dd2c73a1-007d-4c32-3d22-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4873339+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'a4148b25-3152-4355-686f-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Stuurwielbediening',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '9a5b99e4-1dd4-4c5d-b29f-bf1c08cf647f',
#   'salesPrice': 900.0,
#   'salesPriceLabel': '€ 900,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['test:test:test:polySurface1',
#    'Mesh_Volvo_s60_steering_wheel_keys'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682158+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_127',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/ee2cba17-f8b4-449c-84e4-f7a3c2be375d_image.png',
#   'category': None,
#   'categoryId': 'dd2c73a1-007d-4c32-3d22-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4873398+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '2ec93f73-ac57-4c49-6870-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'DAB+ radio',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': 'f7b5a461-e318-4ad3-bb96-8e8df4829f96',
#   'salesPrice': 150.0,
#   'salesPriceLabel': '€ 150,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682173+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_133',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/e00307af-c0c9-4a50-9009-664c1a842b23_image.png',
#   'category': None,
#   'categoryId': '2ad69069-8e98-4034-d91b-08d507486180',
#   'createdDate': '2018-01-25T16:20:08.4873457+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '5a4f610e-0596-4fe1-6872-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Oval',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '8cc947bd-72b2-40e6-b6c5-f1f1228e6526',
#   'salesPrice': 330.0,
#   'salesPriceLabel': '€ 330,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-31T15:30:14.0080576+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_134',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/a207cf87-c201-41e5-a808-c322ed754397_blob',
#   'category': None,
#   'categoryId': '2ad69069-8e98-4034-d91b-08d507486180',
#   'createdDate': '2018-01-25T16:20:08.4873513+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '4184fb87-b578-4aac-6873-08d4ae79a6f8',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Trapezium',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '172804d5-f39b-4709-9fb3-a1e4ae123460',
#   'salesPrice': 450.0,
#   'salesPriceLabel': '€ 450,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.8682205+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'X_135',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/92a2c519-e150-4b51-adf9-03cedb911c18_image.png',
#   'category': None,
#   'categoryId': 'a51f921f-8ba4-47b1-3d23-08d50589c407',
#   'createdDate': '2018-01-25T16:20:08.4873584+01:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '4e6b351d-981b-4795-1092-08d4b0e24cab',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Zeus 19"',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': '6b8b20ae-1226-47dd-9e83-b1bad9759590',
#   'salesPrice': 600.0,
#   'salesPriceLabel': '€ 600,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': ['Style_375_wheel_black_mid_poly_00',
#    'Style_375_wheel_black_mid_poly_03'],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-10-10T12:09:21.868222+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'x_137',
#   'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/db826705-4140-40f6-bead-e985b149005c_image.png',
#   'category': None,
#   'categoryId': '88e43ee0-be1c-4efe-3d21-08d50589c407',
# ...
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '31c09cf6-c76f-4e10-3dc5-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': '850',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-05T22:20:40.5479947+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T21:04:42.1657026+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '1dda83cf-231e-40ec-3dc6-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100000.0,
#   'minValue': 0.0,
#   'name': 'b_min',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-05T22:20:40.5479969+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T21:35:34.5889297+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '11b4ca4c-8616-4813-3dc7-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100000.0,
#   'minValue': 100000.0,
#   'name': 'K',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-09T14:29:05.5814346+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T21:42:32.9760352+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'cbcdb093-cc2b-4caf-3dc8-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100000.0,
#   'minValue': 0.0,
#   'name': 'R',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-05T22:20:40.5480014+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T21:43:09.4382095+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '04f8a770-500a-40bb-3dc9-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100000.0,
#   'minValue': 10000.0,
#   'name': 'A',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-09T14:29:39.8466711+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T21:45:42.9149327+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'ce2f462a-cbe8-4f2a-3dca-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100000.0,
#   'minValue': 0.0,
#   'name': 'H',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-05T22:20:40.548006+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T22:46:33.1385645+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'e55fbdb3-0a3d-4de6-3dcb-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Formule cycle',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-05T22:46:38.817383+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T22:46:58.567611+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '99a013d2-2ef8-447d-3dcc-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100.0,
#   'minValue': 0.0,
#   'name': 'A',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-05T22:47:59.5774438+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-05T22:47:04.0184541+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'dc86b4fe-03e3-4334-3dcd-08d6418c457f',
#   'marginPct': 0.0,
#   'maxValue': 100.0,
#   'minValue': 0.0,
#   'name': 'B',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 1.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-05T22:48:17.0625169+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-10T11:18:12.8721548+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '148dd186-5f52-4010-d6df-08d64619155c',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'A',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-10T11:18:12.8721564+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-10T11:18:17.0913535+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'cc051021-23f6-4adf-d6e0-08d64619155c',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'B',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-10T11:18:17.0913548+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-10T11:18:20.7070762+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'b1873e64-28aa-4138-d6e1-08d64619155c',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'C',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-10T11:18:20.7070776+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': None,
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': None,
#   'createdDate': '2018-11-10T11:34:49.8362481+00:00',
#   'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '482e8bf8-e44e-4c71-d6e2-08d64619155c',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'D',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': None,
#   'updatedDate': '2018-11-10T11:34:49.83625+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'ART-123',
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': '4fde3e79-c90e-4844-3d1b-08d50589c407',
#   'createdDate': '2018-11-13T10:53:54.4606823+00:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'a801b5e5-7746-4ed2-82db-08d649534e0a',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Test feature',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-13T10:53:54.4606838+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'ART-123',
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': '4fde3e79-c90e-4844-3d1b-08d50589c407',
#   'createdDate': '2018-11-13T10:56:18.6182987+00:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': 'b16da3e5-3f2d-4ce0-82dc-08d649534e0a',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Test feature',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-13T10:56:18.6183003+00:00',
#   'vat': None,
#   'vatId': None},
#  {'articleCode': 'ART-123',
#   'cardImageUrl': None,
#   'category': None,
#   'categoryId': '4fde3e79-c90e-4844-3d1b-08d50589c407',
#   'createdDate': '2018-11-13T10:57:46.7378837+00:00',
#   'creatorId': '00000000-0000-0000-0000-000000000000',
#   'customField1': None,
#   'customField2': None,
#   'customField3': None,
#   'customField4': None,
#   'customField5': None,
#   'hiddenThreeDModelItems': [],
#   'id': '1609736d-1987-45ec-82dd-08d649534e0a',
#   'marginPct': 0.0,
#   'maxValue': 0.0,
#   'minValue': 0.0,
#   'name': 'Test feature',
#   'organizationId': None,
#   'organizationName': None,
#   'organizationSellsFeature': None,
#   'packingUnit': 0.0,
#   'properties': None,
#   'reference': None,
#   'salesPrice': 0.0,
#   'salesPriceLabel': '€ 0,00',
#   'stepValue': 0.0,
#   'subcategoryIds': [],
#   'synced': False,
#   'tags': [],
#   'texts': None,
#   'threeDModelItems': [],
#   'type': 0,
#   'unitOfMeasure': None,
#   'unitOfMeasurement': None,
#   'unitOfMeasurementId': '6ba61d80-cf85-4607-570e-08d63e655633',
#   'updatedDate': '2018-11-13T10:57:46.7378853+00:00',
#   'vat': None,
#   'vatId': None}]

# %%
db.first('features', 'description', 'S6000')
# Out:
# {'articleCode': 'X_108',
#  'cardImageUrl': 'https://elfskotcdn.blob.core.windows.net/a4ece79f-f6f0-4c80-9cba-08d4ad0d854f/Elfvo.jpg',
#  'category': None,
#  'categoryId': '4fde3e79-c90e-4844-3d1b-08d50589c407',
#  'createdDate': '2018-01-25T16:20:08.4867666+01:00',
#  'creatorId': '00000000-0000-0000-0000-000000000000',
#  'customField1': None,
#  'customField2': None,
#  'customField3': None,
#  'customField4': None,
#  'customField5': None,
#  'hiddenThreeDModelItems': [],
#  'id': '01574434-b7f4-42d4-b518-08d4ad0fbdd7',
#  'marginPct': 0.0,
#  'maxValue': 0.0,
#  'minValue': 0.0,
#  'name': 'S6000',
#  'organizationId': None,
#  'organizationName': None,
#  'organizationSellsFeature': None,
#  'packingUnit': 0.0,
#  'properties': None,
#  'reference': '01d0e364-5ae1-4506-99a3-935d3634efa4',
#  'salesPrice': 42750.0,
#  'salesPriceLabel': '€ 42.750,00',
#  'stepValue': 0.0,
#  'subcategoryIds': ['5cec6233-c88a-4cca-dbc2-08d5cfa773a6',
#   '5da9354e-60f3-491d-4291-08d5fddd4fac',
#   '831a6ef6-d3d1-48e8-4292-08d5fddd4fac'],
#  'synced': False,
#  'tags': [],
#  'texts': None,
#  'threeDModelItems': [],
#  'type': 0,
#  'unitOfMeasure': None,
#  'unitOfMeasurement': None,
#  'unitOfMeasurementId': None,
#  'updatedDate': '2018-10-31T15:30:14.0080379+00:00',
#  'vat': None,
#  'vatId': None}

# %%
db.first('uom', 'code', 'mm')
# Out:
# {'code': 'mm',
#  'createdDate': '2018-10-30T12:43:54.2744502+00:00',
#  'creatorId': '7c10626d-6d57-403c-ec51-08d56407f341',
#  'customField1': None,
#  'customField2': None,
#  'customField3': None,
#  'customField4': None,
#  'customField5': None,
#  'description': 'Millimeter',
#  'id': '6ba61d80-cf85-4607-570e-08d63e655633',
#  'organizationId': None,
#  'organizationName': None,
#  'reference': None,
#  'synced': False,
#  'updatedDate': '2018-11-09T14:29:39.8466742+00:00'}

# %%
db.help('featuremodels')
# Out:
# Model for featuremodels:
# ['rootFeatureId', 'status', 'revisionOf', 'rootFeature', 'order', 'displayPrices', 'autodeskUrn', 'steps', 'nodes', 'relationships', 'organizationSellsFeatureModels', 'dynamicGroups', 'id', 'organizationId', 'organizationName', 'creatorId', 'reference', 'synced', 'createdDate', 'updatedDate', 'customField1', 'customField2', 'customField3', 'customField4', 'customField5']

# %%
for key in map(lambda x: x['rootFeatureId'], db.all('featuremodels')):
    feature = db.get('features', key)
    print(feature['name'])
# Out:
# S6000
# X8000
# Plateauaanhanger
# TEST relaties
# Betonput
# Test Wessel
# Formule cycle
# b_min

# %%
df = pd.DataFrame()
var = [1,2,3,4,5]
df['var'] = var
df
# Out:
#    var
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
{'yo': 'test'}['yo']
# Out:
# 'test'
