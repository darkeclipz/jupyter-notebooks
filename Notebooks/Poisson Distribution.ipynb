# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# c:\users\isomorphism\appdata\local\programs\python\python36\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['poisson']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Formula

# %% [markdown]
# The Poisson distribution is:

# %% [markdown]
# $$ P(\bar{x}=k)= \dfrac{\lambda^k}{k!}e^{-\lambda} $$

# %% [markdown]
# where $k$ is the discrete probability and $\lambda = E(x) = \text{Var}(X)$.

# %% [markdown]
# # Python example

# %%
def poisson(k, l): return l**k / math.factorial(k) * math.e**(-l)

# %%
x = np.arange(1, 61.8*2, 1)
x-=61.8
x*=.618
x+=61.8
x=np.round(x)
y = [poisson(x, 61.8) for x in x]
plt.figure(figsize=(12,12))
plot(x,y,lw=3)
fill_between(x,y,alpha=0.25)
grid(ls='dashed', alpha=.284)
title('Poisson distribution ($\lambda=61.8$)');
